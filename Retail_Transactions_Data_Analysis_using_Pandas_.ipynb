# %% [markdown]
# <a href="https://colab.research.google.com/github/GreeshmaBodapati/Data-visualization-/blob/main/Retail_Transactions_Data_Analysis_using_Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
datasetpath = "/content/drive/MyDrive/retail_transactions.csv"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
from datetime import datetime

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df['TransactionDate']
# Out:
# 0    2024-01-01
# 1    2024-01-02
# 2    2024-01-03
# 3    2024-01-04
# 4    2024-01-05
#         ...
# 95   2024-04-05
# 96   2024-04-06
# 97   2024-04-07
# 98   2024-04-08
# 99   2024-04-09
# Name: TransactionDate, Length: 100, dtype: datetime64[ns]

# %%
df.columns
# Out:
# Index(['TransactionID', 'TransactionDate', 'StoreID', 'CustomerID',
#        'ProductID', 'ProductCategory', 'Quantity', 'Price', 'PaymentType',
#        'Discount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    object
#  1   TransactionDate  100 non-null    datetime64[ns]
#  2   StoreID          100 non-null    int64
#  3   CustomerID       100 non-null    int64
#  4   ProductID        100 non-null    int64
#  5   ProductCategory  100 non-null    object
#  6   Quantity         100 non-null    int64
#  7   Price            100 non-null    int64
#  8   PaymentType      100 non-null    object
#  9   Discount         75 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#            TransactionDate     StoreID   CustomerID   ProductID    Quantity  \
# count                  100  100.000000   100.000000  100.000000  100.000000
# mean   2024-02-19 12:00:00  102.730000  1552.520000  554.390000    5.370000
# min    2024-01-01 00:00:00  101.000000  1013.000000  501.000000    1.000000
# 25%    2024-01-25 18:00:00  101.000000  1310.250000  529.750000    3.000000
# 50%    2024-02-19 12:00:00  103.000000  1534.000000  554.000000    5.500000
# 75%    2024-03-15 06:00:00  104.000000  1800.750000  579.500000    8.000000
# max    2024-04-09 00:00:00  105.000000  1983.000000  600.000000   10.000000
# std                    NaN    1.384291   268.295461   28.544098    3.013957
#
#            Price   Discount
# count  100.00000  75.000000
# mean   282.15000   7.733333
# min     50.00000   0.000000
# 25%    165.75000   2.500000
# 50%    280.00000  10.000000
# 75%    415.25000  12.500000
# max    500.00000  15.000000
# std    140.19938   5.652871
